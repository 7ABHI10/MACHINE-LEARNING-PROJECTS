# %% [markdown]
# # IPL END to END PROJECT WITH DEPLOYMENT USING STREAMLIT

# %% [markdown]
# # I have deployed the model using Streamlit. In which you can enter Batting and Bowling team name, Runs scored, Target, Overs, Wicket fallen and it will give prediction which team has the highest probality of winning the match.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 23.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Reading Matches Dataset

# %%
matches=pd.read_csv("matches.csv")
matches.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   Season           756 non-null    object
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %% [markdown]
# # Reading Deliveries Dataset

# %%
deliveries=pd.read_csv("deliveries.csv")
deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
deliveries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %% [markdown]
# # Grouping data using columns match_id and inning.

# %%
totalruns_df=deliveries.groupby(['match_id','inning']).sum()

# %%
totalruns_df
# Out:
#                  over  ball  is_super_over  wide_runs  bye_runs  legbye_runs  \
# match_id inning
# 1        1       1312   456              0          5         0            1
#          2       1259   444              0          4         0            1
# 2        1       1323   455              0          6         1            1
#          2       1270   435              0          3         0            1
# 3        1       1280   434              0          2         0            2
# ...               ...   ...            ...        ...       ...          ...
# 11413    2       1301   448              0          4         1            0
# 11414    1       1294   441              0          2         0            5
#          2       1160   413              0          6         0            5
# 11415    1       1287   447              0          3         0            0
#          2       1295   448              0          4         5            0
#
# ...

# %%
totalruns_df=deliveries.groupby(['match_id','inning']).sum()['total_runs'].reset_index()

# %%
totalruns_df
# Out:
#       match_id  inning  total_runs
# 0            1       1         207
# 1            1       2         172
# 2            2       1         184
# 3            2       2         187
# 4            3       1         183
# ...        ...     ...         ...
# 1523     11413       2         170
# 1524     11414       1         155
# 1525     11414       2         162
# 1526     11415       1         152
# 1527     11415       2         157
#
# [1528 rows x 3 columns]

# %% [markdown]
# # Selecting only 1st innings data and removing 2nd innings data from totalruns_df dataframe

# %%
totalruns_df=totalruns_df[totalruns_df['inning']==1]

# %%
totalruns_df
# Out:
#       match_id  inning  total_runs
# 0            1       1         207
# 2            2       1         184
# 4            3       1         183
# 6            4       1         163
# 8            5       1         157
# ...        ...     ...         ...
# 1518     11347       1         143
# 1520     11412       1         136
# 1522     11413       1         171
# 1524     11414       1         155
# 1526     11415       1         152
#
# [756 rows x 3 columns]

# %% [markdown]
# # Adding 1 runs to total_runs column as it is the target to chase using lambda function

# %%
totalruns_df['total_runs']=totalruns_df['total_runs'].map(lambda X:X+1)

# %%
totalruns_df
# Out:
#       match_id  inning  total_runs
# 0            1       1         208
# 2            2       1         185
# 4            3       1         184
# 6            4       1         164
# 8            5       1         158
# ...        ...     ...         ...
# 1518     11347       1         144
# 1520     11412       1         137
# 1522     11413       1         172
# 1524     11414       1         156
# 1526     11415       1         153
#
# [756 rows x 3 columns]

# %% [markdown]
# # Resetting the index

# %%
totalruns_df=totalruns_df.reset_index(drop=True)

# %%
totalruns_df
# Out:
#      match_id  inning  total_runs
# 0           1       1         208
# 1           2       1         185
# 2           3       1         184
# 3           4       1         164
# 4           5       1         158
# ..        ...     ...         ...
# 751     11347       1         144
# 752     11412       1         137
# 753     11413       1         172
# 754     11414       1         156
# 755     11415       1         153
#
# [756 rows x 3 columns]

# %%
matches.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# # Merging totalruns dataframe with Matches dataframe,Where left side merging is done on id of matches and right side merging is done on match_id of totalruns_df

# %%
match_df=matches.merge(totalruns_df[['match_id','total_runs']],left_on="id",right_on="match_id")

# %%
match_df.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
match_df['team1'].value_counts()
# Out:
# Mumbai Indians                 101
# Kings XI Punjab                 91
# Chennai Super Kings             89
# Royal Challengers Bangalore     85
# Kolkata Knight Riders           83
# Delhi Daredevils                72
# Rajasthan Royals                67
# Sunrisers Hyderabad             63
# Deccan Chargers                 43
# Pune Warriors                   20
# Gujarat Lions                   14
# Rising Pune Supergiant           8
# Kochi Tuskers Kerala             7
# Rising Pune Supergiants          7
# Delhi Capitals                   6
# Name: team1, dtype: int64

# %% [markdown]
# # Replacing Delhi daredevils with its new name Delhi Capitals & Replacing Deccan Chargers with its new name Sunrisers Hyderabad

# %%
match_df['team1']=match_df['team1'].str.replace("Delhi Daredevils","Delhi Capitals")
match_df['team2']=match_df['team2'].str.replace("Delhi Daredevils","Delhi Capitals")

# %%
match_df['team1']=match_df['team1'].str.replace("Deccan Chargers","Sunrisers Hyderabad")
match_df['team2']=match_df['team2'].str.replace("Deccan Chargers","Sunrisers Hyderabad")

# %%
match_df['team1'].value_counts()
# Out:
# Sunrisers Hyderabad            106
# Mumbai Indians                 101
# Kings XI Punjab                 91
# Chennai Super Kings             89
# Royal Challengers Bangalore     85
# Kolkata Knight Riders           83
# Delhi Capitals                  78
# Rajasthan Royals                67
# Pune Warriors                   20
# Gujarat Lions                   14
# Rising Pune Supergiant           8
# Kochi Tuskers Kerala             7
# Rising Pune Supergiants          7
# Name: team1, dtype: int64

# %%
match_df['team2'].value_counts()
# Out:
# Delhi Capitals                 99
# Royal Challengers Bangalore    95
# Kolkata Knight Riders          95
# Mumbai Indians                 86
# Kings XI Punjab                85
# Rajasthan Royals               80
# Sunrisers Hyderabad            77
# Chennai Super Kings            75
# Pune Warriors                  26
# Gujarat Lions                  16
# Rising Pune Supergiant          8
# Kochi Tuskers Kerala            7
# Rising Pune Supergiants         7
# Name: team2, dtype: int64

# %% [markdown]
# # Selecting 8 Major teams of IPL

# %%
Teams=['Sunrisers Hyderabad', 'Mumbai Indians', 'Royal Challengers Bangalore',
       'Kolkata Knight Riders', 'Delhi Capitals', 'Kings XI Punjab',
       'Chennai Super Kings', 'Rajasthan Royals']
Teams
# Out:
# ['Sunrisers Hyderabad',
#  'Mumbai Indians',
#  'Royal Challengers Bangalore',
#  'Kolkata Knight Riders',
#  'Delhi Capitals',
#  'Kings XI Punjab',
#  'Chennai Super Kings',
#  'Rajasthan Royals']

# %%
match_df=match_df[match_df['team1'].isin(Teams)]
match_df=match_df[match_df['team2'].isin(Teams)]

# %%
match_df['team1'].value_counts()
# Out:
# Sunrisers Hyderabad            97
# Mumbai Indians                 92
# Kings XI Punjab                83
# Chennai Super Kings            83
# Royal Challengers Bangalore    76
# Kolkata Knight Riders          76
# Delhi Capitals                 70
# Rajasthan Royals               64
# Name: team1, dtype: int64

# %%
match_df['team2'].value_counts()
# Out:
# Delhi Capitals                 91
# Royal Challengers Bangalore    88
# Kolkata Knight Riders          87
# Mumbai Indians                 78
# Kings XI Punjab                78
# Rajasthan Royals               76
# Chennai Super Kings            73
# Sunrisers Hyderabad            70
# Name: team2, dtype: int64

# %% [markdown]
# # Highlighting rows where DL method is applied

# %%
match_df[match_df['dl_applied']==1].style.background_gradient(cmap="plasma")
# Out:
# <style type="text/css">
# #T_d58cc_row0_col0, #T_d58cc_row0_col9, #T_d58cc_row0_col11, #T_d58cc_row0_col18, #T_d58cc_row1_col9, #T_d58cc_row1_col12, #T_d58cc_row2_col9, #T_d58cc_row2_col12, #T_d58cc_row3_col9, #T_d58cc_row3_col11, #T_d58cc_row4_col9, #T_d58cc_row4_col12, #T_d58cc_row5_col9, #T_d58cc_row5_col12, #T_d58cc_row6_col9, #T_d58cc_row6_col12, #T_d58cc_row7_col9, #T_d58cc_row7_col11, #T_d58cc_row7_col19, #T_d58cc_row8_col9, #T_d58cc_row8_col11, #T_d58cc_row9_col9, #T_d58cc_row9_col12, #T_d58cc_row10_col9, #T_d58cc_row10_col11, #T_d58cc_row11_col9, #T_d58cc_row11_col12, #T_d58cc_row12_col9, #T_d58cc_row12_col12, #T_d58cc_row13_col9, #T_d58cc_row13_col11, #T_d58cc_row14_col9, #T_d58cc_row14_col12 {
#   background-color: #0d0887;
#   color: #f1f1f1;
# }
# #T_d58cc_row0_col12 {
#   background-color: #f2844b;
#   color: #f1f1f1;
# }
# #T_d58cc_row0_col19 {
#   background-color: #9613a1;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# # Ignoring matches where DL method is applied

# %%
match_df=match_df[match_df['dl_applied']==0]

# %%
match_df
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# 6        7  IPL-2017         Mumbai  09-04-2017        Kolkata Knight Riders
# 7        8  IPL-2017         Indore  10-04-2017  Royal Challengers Bangalore
# 9       10  IPL-2017         Mumbai  12-04-2017          Sunrisers Hyderabad
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %% [markdown]
# # Creating match_df dataframe using required columns

# %%
match_df=match_df[['match_id','city','winner','total_runs']]

# %%
match_df['winner'].value_counts()
# Out:
# Mumbai Indians                 100
# Chennai Super Kings             93
# Kolkata Knight Riders           81
# Kings XI Punjab                 72
# Royal Challengers Bangalore     69
# Rajasthan Royals                69
# Delhi Daredevils                56
# Sunrisers Hyderabad             48
# Deccan Chargers                 25
# Delhi Capitals                  10
# Name: winner, dtype: int64

# %%
match_df=match_df[match_df['winner'].isin(Teams)]

# %%
match_df['winner'].value_counts()
# Out:
# Mumbai Indians                 100
# Chennai Super Kings             93
# Kolkata Knight Riders           81
# Kings XI Punjab                 72
# Royal Challengers Bangalore     69
# Rajasthan Royals                69
# Sunrisers Hyderabad             48
# Delhi Capitals                  10
# Name: winner, dtype: int64

# %%
match_df
# Out:
#      match_id           city                       winner  total_runs
# 0           1      Hyderabad          Sunrisers Hyderabad         208
# 4           5      Bangalore  Royal Challengers Bangalore         158
# 6           7         Mumbai               Mumbai Indians         179
# 7           8         Indore              Kings XI Punjab         149
# 9          10         Mumbai               Mumbai Indians         159
# ..        ...            ...                          ...         ...
# 751     11347         Mumbai               Mumbai Indians         144
# 752     11412        Chennai               Mumbai Indians         137
# 753     11413  Visakhapatnam               Delhi Capitals         172
# 754     11414  Visakhapatnam          Chennai Super Kings         156
# 755     11415      Hyderabad               Mumbai Indians         153
#
# [542 rows x 4 columns]

# %% [markdown]
# # Merging match_df dataframe with deliveries dataframe

# %%
delivery_df=match_df.merge(deliveries,on="match_id")

# %%
delivery_df.head()
# Out:
#    match_id       city               winner  total_runs_x  inning  \
# 0         1  Hyderabad  Sunrisers Hyderabad           208       1
# 1         1  Hyderabad  Sunrisers Hyderabad           208       1
# 2         1  Hyderabad  Sunrisers Hyderabad           208       1
# 3         1  Hyderabad  Sunrisers Hyderabad           208       1
# 4         1  Hyderabad  Sunrisers Hyderabad           208       1
#
#           batting_team                 bowling_team  over  ball    batsman  \
# 0  Sunrisers Hyderabad  Royal Challengers Bangalore     1     1  DA Warner
# 1  Sunrisers Hyderabad  Royal Challengers Bangalore     1     2  DA Warner
# 2  Sunrisers Hyderabad  Royal Challengers Bangalore     1     3  DA Warner
# 3  Sunrisers Hyderabad  Royal Challengers Bangalore     1     4  DA Warner
# 4  Sunrisers Hyderabad  Royal Challengers Bangalore     1     5  DA Warner
#
#    ... bye_runs legbye_runs  noball_runs  penalty_runs  batsman_runs  \
# ...

# %% [markdown]
# # Selecting only 2nd innings data and removing 1st innings data from delivery_df dataframe

# %%
delivery_df=delivery_df[delivery_df['inning']==2]

# %%
delivery_df.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           208       2
# 126         1  Hyderabad  Sunrisers Hyderabad           208       2
# 127         1  Hyderabad  Sunrisers Hyderabad           208       2
# 128         1  Hyderabad  Sunrisers Hyderabad           208       2
# 129         1  Hyderabad  Sunrisers Hyderabad           208       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... bye_runs legbye_runs  noball_runs  penalty_runs  \
# 125       CH Gayle  ...        0           0            0             0
# ...

# %% [markdown]
# # Finding Current score of particular match

# %%
delivery_df['current_score']=delivery_df.groupby("match_id").cumsum()['total_runs_y']

# %%
delivery_df.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           208       2
# 126         1  Hyderabad  Sunrisers Hyderabad           208       2
# 127         1  Hyderabad  Sunrisers Hyderabad           208       2
# 128         1  Hyderabad  Sunrisers Hyderabad           208       2
# 129         1  Hyderabad  Sunrisers Hyderabad           208       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... legbye_runs noball_runs  penalty_runs  batsman_runs  \
# 125       CH Gayle  ...           0           0             0             1
# ...

# %% [markdown]
# # Finding Runs left to win for particular match

# %%
delivery_df['runs_left']=delivery_df['total_runs_x']-delivery_df['current_score']

# %%
delivery_df.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           208       2
# 126         1  Hyderabad  Sunrisers Hyderabad           208       2
# 127         1  Hyderabad  Sunrisers Hyderabad           208       2
# 128         1  Hyderabad  Sunrisers Hyderabad           208       2
# 129         1  Hyderabad  Sunrisers Hyderabad           208       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... noball_runs penalty_runs  batsman_runs  extra_runs  \
# 125       CH Gayle  ...           0            0             1           0
# ...

# %% [markdown]
# # Finding Balls left in the particular match

# %%
delivery_df['balls_left']=126-(delivery_df['over']*6+delivery_df['ball'])

# %%
delivery_df.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           208       2
# 126         1  Hyderabad  Sunrisers Hyderabad           208       2
# 127         1  Hyderabad  Sunrisers Hyderabad           208       2
# 128         1  Hyderabad  Sunrisers Hyderabad           208       2
# 129         1  Hyderabad  Sunrisers Hyderabad           208       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... penalty_runs batsman_runs  extra_runs  total_runs_y  \
# 125       CH Gayle  ...            0            1           0             1
# ...

# %% [markdown]
# # Replacing player_dismissed names with 0 else 1. 0 means player is Out and 1 means Not Out.

# %%
delivery_df['player_dismissed'].value_counts()
# Out:
# RV Uthappa     57
# V Kohli        56
# RG Sharma      52
# SK Raina       52
# SR Watson      52
#                ..
# AB Barath       1
# AA Bilakhia     1
# R Sharma        1
# KAJ Roach       1
# M Ur Rahman     1
# Name: player_dismissed, Length: 403, dtype: int64

# %%
delivery_df['player_dismissed']=delivery_df['player_dismissed'].fillna(0)

# %%
delivery_df['player_dismissed']=delivery_df['player_dismissed'].apply(lambda x:x if x==0 else 1)

# %%
delivery_df['player_dismissed'].value_counts()
# Out:
# 0    59969
# 1     3102
# Name: player_dismissed, dtype: int64

# %% [markdown]
# # Finding wickets fallen in a particular match

# %%
wickets=delivery_df.groupby("match_id").cumsum()['player_dismissed'].values
wickets
# Out:
# array([0, 0, 0, ..., 6, 6, 7], dtype=int64)

# %%
delivery_df['wickets']=10-wickets

# %%
delivery_df.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           208       2
# 126         1  Hyderabad  Sunrisers Hyderabad           208       2
# 127         1  Hyderabad  Sunrisers Hyderabad           208       2
# 128         1  Hyderabad  Sunrisers Hyderabad           208       2
# 129         1  Hyderabad  Sunrisers Hyderabad           208       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... batsman_runs extra_runs  total_runs_y  \
# 125       CH Gayle  ...            1          0             1
# ...

# %% [markdown]
# # Finding Current run rate in a particular match

# %%
delivery_df['cur_run_rate']=(delivery_df['current_score']*6)/(120-delivery_df['balls_left'])

# %%
delivery_df.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           208       2
# 126         1  Hyderabad  Sunrisers Hyderabad           208       2
# 127         1  Hyderabad  Sunrisers Hyderabad           208       2
# 128         1  Hyderabad  Sunrisers Hyderabad           208       2
# 129         1  Hyderabad  Sunrisers Hyderabad           208       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... extra_runs total_runs_y  player_dismissed  \
# 125       CH Gayle  ...          0            1                 0
# ...

# %% [markdown]
# # Finding Required run rate in a particular match

# %%
delivery_df['req_run_rate']=(delivery_df['runs_left']*6)/(delivery_df['balls_left'])

# %%
delivery_df.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           208       2
# 126         1  Hyderabad  Sunrisers Hyderabad           208       2
# 127         1  Hyderabad  Sunrisers Hyderabad           208       2
# 128         1  Hyderabad  Sunrisers Hyderabad           208       2
# 129         1  Hyderabad  Sunrisers Hyderabad           208       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... total_runs_y player_dismissed  dismissal_kind  \
# 125       CH Gayle  ...            1                0             NaN
# ...

# %% [markdown]
# # Creating Function where batting team is the winner then it will indicate 1 & if bowling team is the winner then it will indicate 0

# %%
def resultfun(row):
    return 1 if row['batting_team']==row['winner'] else 0

# %%
delivery_df['result']=delivery_df.apply(resultfun,axis=1)

# %%
delivery_df.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           208       2
# 126         1  Hyderabad  Sunrisers Hyderabad           208       2
# 127         1  Hyderabad  Sunrisers Hyderabad           208       2
# 128         1  Hyderabad  Sunrisers Hyderabad           208       2
# 129         1  Hyderabad  Sunrisers Hyderabad           208       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... player_dismissed dismissal_kind  fielder  \
# 125       CH Gayle  ...                0            NaN      NaN
# ...

# %%
delivery_df.columns
# Out:
# Index(['match_id', 'city', 'winner', 'total_runs_x', 'inning', 'batting_team',
#        'bowling_team', 'over', 'ball', 'batsman', 'non_striker', 'bowler',
#        'is_super_over', 'wide_runs', 'bye_runs', 'legbye_runs', 'noball_runs',
#        'penalty_runs', 'batsman_runs', 'extra_runs', 'total_runs_y',
#        'player_dismissed', 'dismissal_kind', 'fielder', 'current_score',
#        'runs_left', 'balls_left', 'wickets', 'cur_run_rate', 'req_run_rate',
#        'result'],
#       dtype='object')

# %% [markdown]
# # Creating final-df dataframe which will be used for model building & preediction

# %%
final_df=delivery_df[['batting_team','bowling_team','city','total_runs_x','runs_left','balls_left','wickets','cur_run_rate','req_run_rate','result']]

# %%
final_df.head()
# Out:
#                     batting_team         bowling_team       city  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
#
#      total_runs_x  runs_left  balls_left  wickets  cur_run_rate  req_run_rate  \
# 125           208        207         119       10           6.0     10.436975
# 126           208        207         118       10           3.0     10.525424
# 127           208        207         117       10           2.0     10.615385
# 128           208        205         116       10           4.5     10.603448
# 129           208        201         115       10           8.4     10.486957
#
#      result
# 125       0
# 126       0
# 127       0
# 128       0
# 129       0

# %%
final_df.isnull().sum()
# Out:
# batting_team      0
# bowling_team      0
# city            712
# total_runs_x      0
# runs_left         0
# balls_left        0
# wickets           0
# cur_run_rate      0
# req_run_rate      5
# result            0
# dtype: int64

# %%
final_df=final_df.dropna()

# %%
final_df.isnull().sum()
# Out:
# batting_team    0
# bowling_team    0
# city            0
# total_runs_x    0
# runs_left       0
# balls_left      0
# wickets         0
# cur_run_rate    0
# req_run_rate    0
# result          0
# dtype: int64

# %%
final_df=final_df[final_df['balls_left']!=0]

# %%
final_df.head()
# Out:
#                     batting_team         bowling_team       city  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
#
#      total_runs_x  runs_left  balls_left  wickets  cur_run_rate  req_run_rate  \
# 125           208        207         119       10           6.0     10.436975
# 126           208        207         118       10           3.0     10.525424
# 127           208        207         117       10           2.0     10.615385
# 128           208        205         116       10           4.5     10.603448
# 129           208        201         115       10           8.4     10.486957
#
#      result
# 125       0
# 126       0
# 127       0
# 128       0
# 129       0

# %% [markdown]
# # Dividing final_df dataframe into train X (Features:Independent variable) and Y (Target variable: Dependent Variable)

# %%
X=final_df.drop(['result'],axis=1)
y=final_df['result']

# %% [markdown]
# # Splitting the dataframe into Training and Testing data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=123)

# %%
X_train.shape,y_train.shape
# Out:
# ((49720, 9), (49720,))

# %%
X_test.shape,y_test.shape
# Out:
# ((12431, 9), (12431,))

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn import metrics

# %% [markdown]
# # Selecting all categorical columns and converting it into numerical column by Encoding

# %%
cat_col=final_df.select_dtypes(include=['O']).columns
cat_col
# Out:
# Index(['batting_team', 'bowling_team', 'city'], dtype='object')

# %%
cf=ColumnTransformer([('trf',OneHotEncoder(sparse=False,drop="first"),['batting_team','bowling_team','city'])])

# %% [markdown]
# # Creating Pipeline for model building using Logistic & Random Forest Classifier

# %%
pipe=Pipeline(steps=[('step1',cf),('step2',LogisticRegression(solver="liblinear"))])

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
y_pred=pipe.predict(X_test)

# %%
pipe.predict_proba(X_test)[10]
# Out:
# array([0.77184218, 0.22815782])

# %%
pipe1=Pipeline(steps=[('step1',cf),('step2',RandomForestClassifier())])

# %%
pipe1.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', RandomForestClassifier())])

# %%
pipe1.predict_proba(X_test)[10]
# Out:
# array([1., 0.])

# %% [markdown]
# # Pickling the data

# %%
import pickle
pickle.dump(pipe,open("pipe.pkl","wb"))

# %% [markdown]
# # I have also Deployed the model using Streamlit. In which you can enter batting and bowling team name, Runs scored, Target, Wicket fallen and it will give prediction which team has the highest probality of winning the match.
